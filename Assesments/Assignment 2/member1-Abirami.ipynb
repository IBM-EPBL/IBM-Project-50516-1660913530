# %%
'''Build a python code, assume u get temp and humidity values
	 (generated with random function to a variable) and write a
	conditon to continuously detect alarm in
	 case of high temperature'''
	#import the necessary package!
import requests
import random
from time import *
gate=True
#input the city name
def run_city():
  city = input('input the city name')
  print(city)
	

	# or you can also hard-code the value
	

	

	#Display the message!
  print('Displaying Weater report for: ' + city)
	

	#fetch the weater details
  url = 'https://wttr.in/{}'.format(city)
  res = requests.get(url)
	

	#display the result!
  print(res.text)
	

	#temprature searching
while(gate):
    temperature = random.randint(0,50)
    humidity = random.randint(10,50)
    if temperature>45 and humidity<50:
        print("Temperature =",temperature,"Humidity =",humidity)
        print("Alert message in Activate")
        gate=False
    else:
        print("Temperature =",temperature,"Humidity",humidity)
    sleep(1);
	

	#enter temprature value
x= int(input("Please enter the Humidity value :"))
y= int(input("Please enter the temperature value  :"))
z=print(x,y)
print(z)
if x == 36.5:
    print("Due to Temperature report you are in normal days")
if x < 36:
        print("your Temperature is low compare to normal days")
if x > 36:
            print("your Temperature is high compare to normal days")
if y == 45:
    print("Due to Humidity report you are in normal place")
if y < 45:
        print("your Humidity is low compare to normal days")
if y > 45:
            print("your Humidity is high compare to normal days")
	

	

	

	

	

while True:
    run_city()
# Out:
# Temperature = 45 Humidity 35
# Temperature = 1 Humidity 14
# Temperature = 31 Humidity 21
# Temperature = 37 Humidity 35
# Temperature = 30 Humidity 16
# Temperature = 7 Humidity 49
# Temperature = 28 Humidity 46
# Temperature = 27 Humidity 25
# Temperature = 19 Humidity 24
# Temperature = 18 Humidity 16
# Temperature = 36 Humidity 35
# Temperature = 8 Humidity 43
# Temperature = 22 Humidity 23
# Temperature = 7 Humidity 24
# Temperature = 45 Humidity 41
# Temperature = 40 Humidity 32
# Temperature = 7 Humidity 15
# Temperature = 38 Humidity 33
# Temperature = 23 Humidity 42
# Temperature = 43 Humidity 10
# Temperature = 7 Humidity 18
# Temperature = 28 Humidity 39
# Temperature = 13 Humidity 38
# Temperature = 21 Humidity 47
# Temperature = 42 Humidity 21
# Temperature = 21 Humidity 20
# Temperature = 32 Humidity 12
# Temperature = 20 Humidity 24
# Temperature = 25 Humidity 47
# Temperature = 8 Humidity 16
# Temperature = 33 Humidity 22
# Temperature = 17 Humidity 36
# Temperature = 43 Humidity 35
# Temperature = 7 Humidity 25
# Temperature = 32 Humidity 21
# Temperature = 36 Humidity 31
# Temperature = 41 Humidity 32
# Temperature = 33 Humidity 36
# Temperature = 1 Humidity 38
# Temperature = 9 Humidity 41
# Temperature = 17 Humidity 44
# Temperature = 23 Humidity 16
# Temperature = 44 Humidity 12
# Temperature = 37 Humidity 45
# Temperature = 9 Humidity 20
# Temperature = 18 Humidity 11
# Temperature = 12 Humidity 43
# Temperature = 7 Humidity 13
# Temperature = 16 Humidity 27
# Temperature = 30 Humidity 46
# Temperature = 48 Humidity = 13
# Alert message in Activate
# Please enter the Humidity value :13
# Please enter the temperature value  :7
# 13 7
# None
# your Temperature is low compare to normal days
# your Humidity is low compare to normal days
# input the city nameneyveli
# neyveli
# Displaying Weater report for: neyveli
# Weather report: neyveli
#
#    _`/"".-.     Patchy rain possible
#     ,\_(   ).   +34(38) °C
#      /(___(__)  ← 10 km/h
#        ‘ ‘ ‘ ‘  10 km
#       ‘ ‘ ‘ ‘   0.1 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain po…│    \  /       Partly cloudy  │     \   /     Clear          │    \  /       Partly cloudy  │
# │   ,\_(   ).   +32(35) °C     │  _ /"".-.     +36(40) °C     │      .-.      +29(33) °C     │  _ /"".-.     +28(31) °C     │
# │    /(___(__)  ↗ 12-15 km/h   │    \_(   ).   ↗ 6-8 km/h     │   ― (   ) ―   ↖ 14-24 km/h   │    \_(   ).   ↘ 5-9 km/h     │
# │      ‘ ‘ ‘ ‘  9 km           │    /(___(__)  10 km          │      `-’      10 km          │    /(___(__)  10 km          │
# │     ‘ ‘ ‘ ‘   0.2 mm | 71%   │               0.0 mm | 0%    │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 27 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │    \  /       Partly cloudy  │    \  /       Partly cloudy  │    \  /       Partly cloudy  │
# │      .-.      +32(35) °C     │  _ /"".-.     +37(40) °C     │  _ /"".-.     +30(34) °C     │  _ /"".-.     +30(33) °C     │
# │   ― (   ) ―   → 12-14 km/h   │    \_(   ).   ↘ 13-15 km/h   │    \_(   ).   ↖ 6-9 km/h     │    \_(   ).   ↖ 9-14 km/h    │
# │      `-’      10 km          │    /(___(__)  10 km          │    /(___(__)  10 km          │    /(___(__)  10 km          │
# │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 28 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │               Cloudy         │    \  /       Partly cloudy  │
# │  _ /"".-.     +31(35) °C     │  _ /"".-.     +36(40) °C     │      .--.     +31(35) °C     │  _ /"".-.     +29(33) °C     │
# │    \_(   ).   → 13-15 km/h   │    \_(   ).   → 13-15 km/h   │   .-(    ).   ↖ 7-11 km/h    │    \_(   ).   ↑ 18-27 km/h   │
# │    /(___(__)  10 km          │    /(___(__)  10 km          │  (___.__)__)  10 km          │    /(___(__)  10 km          │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Neyveli, South Arcot, Cuddalore district, Tamil Nadu, 607803, India [11.535987,79.4824392]
#
# Follow @igor_chubin for wttr.in updates
#
# input the city namevillupuram
# villupuram
# Displaying Weater report for: villupuram
# Weather report: villupuram
#
#                 Cloudy
#        .--.     +33(37) °C
#     .-(    ).   ← 15 km/h
#    (___.__)__)  10 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │    \  /       Partly cloudy  │  _`/"".-.     Patchy rain po…│    \  /       Partly cloudy  │
# │      .-.      +32(35) °C     │  _ /"".-.     +36(39) °C     │   ,\_(   ).   +29(32) °C     │  _ /"".-.     +28(31) °C     │
# │   ― (   ) ―   ↗ 11-13 km/h   │    \_(   ).   → 7-8 km/h     │    /(___(__)  ← 7-13 km/h    │    \_(   ).   → 8-15 km/h    │
# │      `-’      10 km          │    /(___(__)  10 km          │      ‘ ‘ ‘ ‘  9 km           │    /(___(__)  10 km          │
# │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │     ‘ ‘ ‘ ‘   0.4 mm | 89%   │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 27 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │    \  /       Partly cloudy  │               Overcast       │    \  /       Partly cloudy  │
# │      .-.      +32(34) °C     │  _ /"".-.     +36(40) °C     │      .--.     +31(34) °C     │  _ /"".-.     +30(33) °C     │
# │   ― (   ) ―   → 13-15 km/h   │    \_(   ).   ↘ 13-14 km/h   │   .-(    ).   ← 2-4 km/h     │    \_(   ).   ↖ 13-22 km/h   │
# │      `-’      10 km          │    /(___(__)  10 km          │  (___.__)__)  10 km          │    /(___(__)  10 km          │
# │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 28 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │    \  /       Partly cloudy  │               Cloudy         │               Cloudy         │
# │      .-.      +33(36) °C     │  _ /"".-.     +37(40) °C     │      .--.     +31(34) °C     │      .--.     +30(33) °C     │
# │   ― (   ) ―   → 13-15 km/h   │    \_(   ).   → 13-15 km/h   │   .-(    ).   ↖ 10-17 km/h   │   .-(    ).   ↑ 10-18 km/h   │
# │      `-’      10 km          │    /(___(__)  10 km          │  (___.__)__)  10 km          │  (___.__)__)  10 km          │
# │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Villupuram Municipality Park, Viluppuram, Viluppuram district, Tamil Nadu, 605600, India [11.9398285,79.4945645]
#
# Follow @igor_chubin for wttr.in updates
# input the city namechennai
# chennai
# Displaying Weater report for: chennai
# Weather report: chennai
#
#      \  /       Partly cloudy
#    _ /"".-.     +35(47) °C
#      \_(   ).   ↑ 9 km/h
#      /(___(__)  6 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │    \  /       Partly cloudy  │  _`/"".-.     Patchy rain po…│  _`/"".-.     Patchy rain po…│
# │      .-.      +32(36) °C     │  _ /"".-.     +32(37) °C     │   ,\_(   ).   +29(34) °C     │   ,\_(   ).   +29(33) °C     │
# │   ― (   ) ―   ↗ 8-10 km/h    │    \_(   ).   ↖ 19-22 km/h   │    /(___(__)  ↖ 9-14 km/h    │    /(___(__)  ↑ 11-18 km/h   │
# │      `-’      10 km          │    /(___(__)  10 km          │      ‘ ‘ ‘ ‘  9 km           │      ‘ ‘ ‘ ‘  9 km           │
# │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │     ‘ ‘ ‘ ‘   0.3 mm | 73%   │     ‘ ‘ ‘ ‘   0.2 mm | 67%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 27 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │  _`/"".-.     Patchy rain po…│  _`/"".-.     Thundery outbr…│
# │  _ /"".-.     +31(35) °C     │  _ /"".-.     +34(40) °C     │   ,\_(   ).   +30(35) °C     │   ,\_(   ).   +30(35) °C     │
# │    \_(   ).   ↗ 13-16 km/h   │    \_(   ).   ↖ 8-9 km/h     │    /(___(__)  ↖ 14-19 km/h   │    /(___(__)  ↖ 11-16 km/h   │
# │    /(___(__)  10 km          │    /(___(__)  10 km          │      ‘ ‘ ‘ ‘  9 km           │     ⚡‘‘⚡‘‘  9 km           │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │     ‘ ‘ ‘ ‘   0.2 mm | 69%   │     ‘ ‘ ‘ ‘   0.1 mm | 85%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 28 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain po…│    \  /       Partly cloudy  │  _`/"".-.     Thundery outbr…│  _`/"".-.     Patchy rain po…│
# │   ,\_(   ).   +31(35) °C     │  _ /"".-.     +33(39) °C     │   ,\_(   ).   +30(36) °C     │   ,\_(   ).   +30(36) °C     │
# │    /(___(__)  ↗ 13-19 km/h   │    \_(   ).   ↖ 5-6 km/h     │    /(___(__)  ↖ 13-19 km/h   │    /(___(__)  ↖ 12-20 km/h   │
# │      ‘ ‘ ‘ ‘  9 km           │    /(___(__)  10 km          │     ⚡‘‘⚡‘‘  9 km           │      ‘ ‘ ‘ ‘  10 km          │
# │     ‘ ‘ ‘ ‘   0.4 mm | 80%   │               0.0 mm | 0%    │     ‘ ‘ ‘ ‘   0.1 mm | 81%   │     ‘ ‘ ‘ ‘   0.1 mm | 84%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Corporation of Chennai, Chennai district, Tamil Nadu, India [13.0801721,80.2838331]
#
# Follow @igor_chubin for wttr.in updates
#
# input the city nameandimadam
# andimadam
# Displaying Weater report for: andimadam
# >>>    _  _    ___  _  _
# >>>   | || |  / _ \| || |
# >>>   | || |_| | | | || |_
# >>>   |__   _| |_| |__   _|
# >>>      |_|  \___/   |_|
# >>>
# >>>   404 UNKNOWN LOCATION: andimadam
# >>>
# ----
# Weather report: Oymyakon
#
#                 Overcast
#        .--.     0 °C
#     .-(    ).   ↙ 4 km/h
#    (___.__)__)  10 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Cloudy         │    \  /       Partly cloudy  │     \   /     Sunny          │     \   /     Clear          │
# │      .--.     -8(-10) °C     │  _ /"".-.     -4 °C          │      .-.      -2 °C          │      .-.      -6(-8) °C      │
# │   .-(    ).   ↖ 4-6 km/h     │    \_(   ).   ← 3-4 km/h     │   ― (   ) ―   ↖ 1 km/h       │   ― (   ) ―   ↑ 4-8 km/h     │
# │  (___.__)__)  10 km          │    /(___(__)  10 km          │      `-’      10 km          │      `-’      10 km          │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │     /   \     0.0 mm | 0%    │     /   \     0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 27 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Overcast       │     \   /     Sunny          │               Cloudy         │               Overcast       │
# │      .--.     -7 °C          │      .-.      -3 °C          │      .--.     -2 °C          │      .--.     -4(-5) °C      │
# │   .-(    ).   ↑ 2-4 km/h     │   ― (   ) ―   ↙ 2-3 km/h     │   .-(    ).   ↘ 1-3 km/h     │   .-(    ).   → 3-7 km/h     │
# │  (___.__)__)  10 km          │      `-’      10 km          │  (___.__)__)  10 km          │  (___.__)__)  10 km          │
# │               0.0 mm | 0%    │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 28 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │               Overcast       │               Overcast       │
# │  _ /"".-.     -6 °C          │  _ /"".-.     -3 °C          │      .--.     -2 °C          │      .--.     -4 °C          │
# │    \_(   ).   ↖ 3-5 km/h     │    \_(   ).   ↙ 2-3 km/h     │   .-(    ).   ↓ 1 km/h       │   .-(    ).   → 3-6 km/h     │
# │    /(___(__)  10 km          │    /(___(__)  10 km          │  (___.__)__)  10 km          │  (___.__)__)  10 km          │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#  We were unable to find your location
#  so we have brought you to Oymyakon,
#  one of the coldest permanently inhabited locales on the planet.
#
# Follow @igor_chubin for wttr.in updates
# input the city nameariyalur
# ariyalur
# Displaying Weater report for: ariyalur
# Weather report: ariyalur
#
#      \  /       Partly cloudy
#    _ /"".-.     +35(39) °C
#      \_(   ).   ↑ 9 km/h
#      /(___(__)  10 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │    \  /       Partly cloudy  │     \   /     Clear          │    \  /       Partly cloudy  │
# │      .-.      +30(33) °C     │  _ /"".-.     +35(39) °C     │      .-.      +29(33) °C     │  _ /"".-.     +27(31) °C     │
# │   ― (   ) ―   ↗ 15-19 km/h   │    \_(   ).   ↗ 14-17 km/h   │   ― (   ) ―   ↖ 14-22 km/h   │    \_(   ).   ↑ 14-25 km/h   │
# │      `-’      10 km          │    /(___(__)  10 km          │      `-’      10 km          │    /(___(__)  10 km          │
# │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 27 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │               Cloudy         │    \  /       Partly cloudy  │  _`/"".-.     Patchy rain po…│
# │      .-.      +32(35) °C     │      .--.     +36(40) °C     │  _ /"".-.     +30(34) °C     │   ,\_(   ).   +28(32) °C     │
# │   ― (   ) ―   → 14-16 km/h   │   .-(    ).   → 9-11 km/h    │    \_(   ).   ← 6-10 km/h    │    /(___(__)  ↖ 13-21 km/h   │
# │      `-’      10 km          │  (___.__)__)  10 km          │    /(___(__)  10 km          │      ‘ ‘ ‘ ‘  9 km           │
# │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │     ‘ ‘ ‘ ‘   0.2 mm | 87%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 28 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │     \   /     Sunny          │  _`/"".-.     Patchy rain po…│  _`/"".-.     Patchy rain po…│
# │      .-.      +31(35) °C     │      .-.      +36(41) °C     │   ,\_(   ).   +29(33) °C     │   ,\_(   ).   +29(33) °C     │
# │   ― (   ) ―   ↗ 20-23 km/h   │   ― (   ) ―   → 18-20 km/h   │    /(___(__)  ↖ 6-10 km/h    │    /(___(__)  ↑ 18-30 km/h   │
# │      `-’      10 km          │      `-’      10 km          │      ‘ ‘ ‘ ‘  9 km           │      ‘ ‘ ‘ ‘  10 km          │
# │     /   \     0.0 mm | 0%    │     /   \     0.0 mm | 0%    │     ‘ ‘ ‘ ‘   0.3 mm | 86%   │     ‘ ‘ ‘ ‘   0.1 mm | 84%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Ariyalur, Ariyalur district, Tamil Nadu, 621704, India [11.1357708,79.0723203]
#
# Follow @igor_chubin for wttr.in updates
#
# input the city namevirudhachalam
# virudhachalam
# Displaying Weater report for: virudhachalam
# Weather report: virudhachalam
#
#      \  /       Partly cloudy
#    _ /"".-.     +36(39) °C
#      \_(   ).   ↖ 6 km/h
#      /(___(__)  10 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain po…│    \  /       Partly cloudy  │    \  /       Partly cloudy  │  _`/"".-.     Patchy rain po…│
# │   ,\_(   ).   +30(33) °C     │  _ /"".-.     +36(41) °C     │  _ /"".-.     +31(34) °C     │   ,\_(   ).   +27(30) °C     │
# │    /(___(__)  ↗ 5-7 km/h     │    \_(   ).   ↑ 0 km/h       │    \_(   ).   ← 12-19 km/h   │    /(___(__)  ↑ 11-20 km/h   │
# │      ‘ ‘ ‘ ‘  10 km          │    /(___(__)  10 km          │    /(___(__)  10 km          │      ‘ ‘ ‘ ‘  9 km           │
# │     ‘ ‘ ‘ ‘   0.1 mm | 75%   │               0.0 mm | 0%    │               0.0 mm | 0%    │     ‘ ‘ ‘ ‘   0.3 mm | 66%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 27 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │    \  /       Partly cloudy  │               Cloudy         │
# │  _ /"".-.     +32(35) °C     │  _ /"".-.     +37(41) °C     │  _ /"".-.     +30(34) °C     │      .--.     +30(33) °C     │
# │    \_(   ).   → 12-14 km/h   │    \_(   ).   ↘ 14-16 km/h   │    \_(   ).   ↖ 11-19 km/h   │   .-(    ).   ↑ 5-8 km/h     │
# │    /(___(__)  10 km          │    /(___(__)  10 km          │    /(___(__)  10 km          │  (___.__)__)  10 km          │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 28 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │     \   /     Clear          │               Cloudy         │
# │  _ /"".-.     +32(35) °C     │  _ /"".-.     +35(39) °C     │      .-.      +29(32) °C     │      .--.     +29(32) °C     │
# │    \_(   ).   ↗ 13-15 km/h   │    \_(   ).   ↘ 9-11 km/h    │   ― (   ) ―   ↑ 16-28 km/h   │   .-(    ).   ↑ 14-21 km/h   │
# │    /(___(__)  10 km          │    /(___(__)  10 km          │      `-’      10 km          │  (___.__)__)  10 km          │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Virudhachalam, Cuddalore District, Tamil Nadu, भारत / India [11.54787515,79.38453998266513]
#
# Follow @igor_chubin for wttr.in updates
# input the city nameAndimadam
# Andimadam
# Displaying Weater report for: Andimadam
# >>>    _  _    ___  _  _
# >>>   | || |  / _ \| || |
# >>>   | || |_| | | | || |_
# >>>   |__   _| |_| |__   _|
# >>>      |_|  \___/   |_|
# >>>
# >>>   404 UNKNOWN LOCATION: Andimadam
# >>>
# ----
# Weather report: Oymyakon
#
#                 Overcast
#        .--.     0 °C
#     .-(    ).   ↙ 4 km/h
#    (___.__)__)  10 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Cloudy         │    \  /       Partly cloudy  │     \   /     Sunny          │     \   /     Clear          │
# │      .--.     -8(-10) °C     │  _ /"".-.     -4 °C          │      .-.      -2 °C          │      .-.      -6(-8) °C      │
# │   .-(    ).   ↖ 4-6 km/h     │    \_(   ).   ← 3-4 km/h     │   ― (   ) ―   ↖ 1 km/h       │   ― (   ) ―   ↑ 4-8 km/h     │
# │  (___.__)__)  10 km          │    /(___(__)  10 km          │      `-’      10 km          │      `-’      10 km          │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │     /   \     0.0 mm | 0%    │     /   \     0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 27 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Overcast       │     \   /     Sunny          │               Cloudy         │               Overcast       │
# │      .--.     -7 °C          │      .-.      -3 °C          │      .--.     -2 °C          │      .--.     -4(-5) °C      │
# │   .-(    ).   ↑ 2-4 km/h     │   ― (   ) ―   ↙ 2-3 km/h     │   .-(    ).   ↘ 1-3 km/h     │   .-(    ).   → 3-7 km/h     │
# │  (___.__)__)  10 km          │      `-’      10 km          │  (___.__)__)  10 km          │  (___.__)__)  10 km          │
# │               0.0 mm | 0%    │     /   \     0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 28 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │               Overcast       │               Overcast       │
# │  _ /"".-.     -6 °C          │  _ /"".-.     -3 °C          │      .--.     -2 °C          │      .--.     -4 °C          │
# │    \_(   ).   ↖ 3-5 km/h     │    \_(   ).   ↙ 2-3 km/h     │   .-(    ).   ↓ 1 km/h       │   .-(    ).   → 3-6 km/h     │
# │    /(___(__)  10 km          │    /(___(__)  10 km          │  (___.__)__)  10 km          │  (___.__)__)  10 km          │
# │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │               0.0 mm | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#  We were unable to find your location
#  so we have brought you to Oymyakon,
#  one of the coldest permanently inhabited locales on the planet.
#
# Follow @igor_chubin for wttr.in updates
#
# input the city namesilambur
# silambur
# Displaying Weater report for: silambur
